# %%
import pandas as pd
import os 
import ast

import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import numpy as np

# %% [markdown]
# Load data

# %%
filepath = '../data/fma_metadata/tracks.csv'
tracks = pd.read_csv(filepath, index_col=0, header=[0, 1])
tracks.head()
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#                                                                           \
#          favorites id                                information listens
# track_id
# 2                4  1                                    <p></p>    6073
# 3                4  1                                    <p></p>    6073
# 5                4  1                                    <p></p>    6073
# 10               4  6                                        NaN   47632
# 20               2  4  <p> "spiritual songs" from Nicky Cook</p>    2710
#
#                         ...       track                         \
#          producer tags  ... information interest language_code
# track_id                ...
# 2             NaN   []  ...         NaN     4656            en
# 3             NaN   []  ...         NaN     1470            en
# 5             NaN   []  ...         NaN     1933            en
# 10            NaN   []  ...         NaN    54881            en
# 20            NaN   []  ...         NaN      978            en
#
#                                                                               \
#                                                     license listens lyricist
# track_id
# 2         Attribution-NonCommercial-ShareAlike 3.0 Inter...    1293      NaN
# 3         Attribution-NonCommercial-ShareAlike 3.0 Inter...     514      NaN
# 5         Attribution-NonCommercial-ShareAlike 3.0 Inter...    1151      NaN
# 10        Attribution-NonCommercial-NoDerivatives (aka M...   50135      NaN
# 20        Attribution-NonCommercial-NoDerivatives (aka M...     361      NaN
#
#
#          number publisher tags            title
# track_id
# 2             3       NaN   []             Food
# 3             4       NaN   []     Electric Ave
# 5             6       NaN   []       This World
# 10            1       NaN   []          Freeway
# 20            3       NaN   []  Spiritual Level
#
# [5 rows x 52 columns]

# %%
keep_cols =  [('set', 'split'), ('set', 'subset'),('track', 'genre_top'), ('track', 'genres')]
tracks = tracks[keep_cols]
tracks.head()
# Out:
#                set             track
#              split  subset genre_top     genres
# track_id
# 2         training   small   Hip-Hop       [21]
# 3         training  medium   Hip-Hop       [21]
# 5         training   small   Hip-Hop       [21]
# 10        training   small       Pop       [10]
# 20        training   large       NaN  [76, 103]

# %% [markdown]
# Analyzing MFCC features

# %%
filepath = '../data/fma_metadata/features.csv'
features = pd.read_csv(filepath, index_col=0, header=[0, 1, 2], skip_blank_lines=True )

# %%
mfcc = features['mfcc']
mfcc.head()
# Out:
# statistics   kurtosis                                                    \
# number             01        02        03        04        05        06
# track_id
# 2            3.856789  1.541901  0.000816  0.330728  0.118731 -0.342687
# 3            4.296755  1.399977  0.112535 -0.211170  0.032953 -0.023489
# 5            2.624517  2.415293  0.440233 -0.782131 -0.771069 -0.724216
# 10           5.076893  1.161854  2.095651  1.372743 -0.203574 -0.345354
# 20          11.880132  4.085320  0.002655  1.518562  0.181947  0.339014
#
# statistics                                          ...        std             \
# number            07        08        09        10  ...         11         12
# track_id                                            ...
# 2          -0.259252  0.146735  0.410656 -0.162872  ...  10.059609   8.601942
# 3           0.150404  0.046454  0.033484 -0.064596  ...   8.771966  10.026867
# 5           0.090260  0.152119  0.261731 -0.608905  ...   8.863638   9.581952
# 10         -0.529139  0.561974  0.281350 -0.150672  ...   8.289734   7.985110
# 20          0.367611  0.069932 -0.016032  0.026012  ...   7.706648   6.498904
#
# statistics                                                              \
# number            13        14        15        16        17        18
# track_id
# 2           9.284250  9.245516  8.520863  8.560472  7.651871  7.246555
# 3           6.978541  7.650417  9.600357  7.222888  8.398293  7.285423
# 5           8.895723  8.141456  8.201844  7.780963  7.132692  7.539753
# 10          7.075400  6.972649  7.071393  7.270959  7.051070  6.928591
# 20          6.845514  6.934421  7.019398  6.983841  6.813648  7.520811
#
# statistics
# number            19        20
# track_id
# 2           7.077188  7.391859
# 3           7.417791  8.777440
# 5           8.452527  7.334442
# 10          6.430473  6.186294
# 20          7.098001  7.032246
#
# [5 rows x 140 columns]

# %%
small = tracks['set', 'subset'] == 'small'

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[small & train, ('track', 'genre_top')]
y_val = tracks.loc[small & val, ('track', 'genre_top')]
y_test = tracks.loc[small & test, ('track', 'genre_top')]

X_train_mfcc = features.loc[small & train, 'mfcc']
X_val_mfcc = features.loc[small & val, 'mfcc']
X_test_mfcc = features.loc[small & test, 'mfcc']

print(f'Training examples: {y_train.size}')
# Out:
# Training examples: 6400

# %% [markdown]
# Standarize the features

# %%
#Shuffle training features
X_train, y_train = skl.utils.shuffle(X_train_mfcc, y_train, random_state=42)

#Standard Scaling features
scaler = skl.preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val_mfcc)
X_test = scaler.transform(X_test_mfcc)

print(X_train.shape, y_train.shape)
# Out:
# (6400, 140) (6400,)

# %%
#Create a label encoder
le = skl.preprocessing.LabelEncoder()

#Fit transform all y's
y_train = le.fit_transform(y_train)
y_val = le.fit_transform(y_val)
y_test = le.fit_transform(y_test)

# %% [markdown]
# Building the baseline model

# %%
from sklearn.metrics import f1_score
from time import time

# %%
def train_classifier(clf, X_train, y_train):
    #Start clock, train model, end clock
    start = time()
    clf.fit(X_train, y_train)
    end = time()
    
    print(f'Elapsed training time: {end - start}')

# %%
def predict_labels(clf, features, target):
    
    start = time()
    y_pred = clf.predict(features)
    end = time()
    
    print(f'Elapsed prediction time: {end - start}')
    return f1_score(target, y_pred, average='micro', pos_label=1)

# %%
def train_predict(clf, X_train, y_train, X_test, y_test):
    
    #Print classifier being used
    print(f'Training a {clf.__class__.__name__}')
    
    
    #Train the classifier
    train_classifier(clf, X_train, y_train)
    
    #Result of predictions
    print(f'F1 Score for training set: {predict_labels(clf, X_train, y_train)}')
    print(f'F1 Score for testing set: {predict_labels(clf, X_test, y_test)}\n')

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

#Initialize instances of all models
clf_dtc = DecisionTreeClassifier(random_state=10, max_depth=4)
clf_svc = SVC()
clf_lr = LogisticRegression(max_iter=100)
clf_rfc = RandomForestClassifier(random_state=10, max_depth=30, n_estimators=300, min_samples_leaf=6, min_impurity_decrease=0.0002,
                     class_weight='balanced')

# %%
for clf in [clf_dtc, clf_svc, clf_lr, clf_rfc]:
    print(f'Model: {clf.__class__.__name__}')
    train_predict(clf, X_train, y_train, X_test, y_test)
# Out:
# Model: DecisionTreeClassifier
# Training a DecisionTreeClassifier
# Elapsed training time: 0.41300511360168457
# Elapsed prediction time: 0.0018661022186279297
# F1 Score for training set: 0.36250000000000004
# Elapsed prediction time: 0.00046896934509277344
# F1 Score for testing set: 0.28
#
# Model: SVC
# Training a SVC
# Elapsed training time: 8.828726053237915
# Elapsed prediction time: 6.711821794509888
# F1 Score for training set: 0.758125
# Elapsed prediction time: 0.8418619632720947
# F1 Score for testing set: 0.46375
#
# Model: LogisticRegression
# Training a LogisticRegression
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Elapsed training time: 0.538189172744751
# Elapsed prediction time: 0.002214193344116211
# F1 Score for training set: 0.56046875
# Elapsed prediction time: 0.0006189346313476562
# F1 Score for testing set: 0.42125
#
# Model: RandomForestClassifier
# Training a RandomForestClassifier
# Elapsed training time: 13.599556922912598
# Elapsed prediction time: 0.3825860023498535
# F1 Score for training set: 0.92671875
# Elapsed prediction time: 0.0679628849029541
# F1 Score for testing set: 0.4375

# %%
# Out:
# Training a SVC
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-0a3450d225c3> in <module>
#       1 clf_svc2 = SVC()
# ----> 2 train_predict(clf_svc2, X_train, y_train, X_test, y_test)
#
# <ipython-input-12-75784bca53e3> in train_predict(clf, X_train, y_train, X_test, y_test)
#       6
#       7     #Train the classifier
# ----> 8     train_classifier(clf, X_train, y_train)
#       9
#      10     #Result of predictions
#
# <ipython-input-10-96d02266669e> in train_classifier(clf, X_train, y_train)
#       2     #Start clock, train model, end clock
#       3     start = time()
# ----> 4     clf.fit(X_train, y_train)
#       5     end = time()
#       6
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     158             check_consistent_length(X, y)
#     159         else:
# --> 160             X, y = self._validate_data(X, y, dtype=np.float64,
#     161                                        order='C', accept_sparse='csr',
#     162                                        accept_large_sparse=False)
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     639             array = array.astype(np.float64)
#     640         if not allow_nd and array.ndim >= 3:
# --> 641             raise ValueError("Found array with dim %d. %s expected <= 2."
#     642                              % (array.ndim, estimator_name))
#     643
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
X_train.shape
# Out:
# (6394, 640, 128)

# %%
y_train.shape
# Out:
# (6394,)

# %%
pd.DataFrame(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-eaef8427e30a> in <module>
# ----> 1 pd.DataFrame(X_train)
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     494                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     495             else:
# --> 496                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     497
#     498         # For data is list-like, or Iterable (will consume into list)
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     188     # by definition an array here
#     189     # the dtypes will be coerced to a single dtype
# --> 190     values = _prep_ndarray(values, copy=copy)
#     191
#     192     if dtype is not None:
#
# //anaconda3/envs/aa/lib/python3.8/site-packages/pandas/core/internals/construction.py in _prep_ndarray(values, copy)
#     322         values = values.reshape((values.shape[0], 1))
#     323     elif values.ndim != 2:
# --> 324         raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     325
#     326     return values
#
# ValueError: Must pass 2-d input. shape=(6394, 640, 128)
